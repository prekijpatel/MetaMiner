# %%
import geopandas as gpd
import os
import tqdm as tqdm
import pandas as pd

# %%
filepath = 'C:/Users/Prekij/Downloads/Compressed/gadm_410-levels.gpkg'

# %%
filepath
# Out:
# 'C:/Users/Prekij/Downloads/Compressed/gadm_410-levels.gpkg'

# %%
adm1_layers = gpd.read_file(filepath, layer = 'ADM_1')

# %%
adm0_layers = gpd.read_file(filepath, layer = 'ADM_0')

# %%
print(adm1_layers.head())
# print(adm0_layers.head())
# Out:
#   GID_0      COUNTRY    GID_1      NAME_1                  VARNAME_1  \
# 0   AFG  Afghanistan  AFG.1_1  Badakhshan                   Badahšan
# 1   AFG  Afghanistan  AFG.2_1     Badghis   Badghes|Badghisat|Badgis
# 2   AFG  Afghanistan  AFG.3_1     Baghlan             Baglan|Bughlan
# 3   AFG  Afghanistan  AFG.4_1       Balkh  Balh|Mazar-i-Sharif|Mazar
# 4   AFG  Afghanistan  AFG.5_1      Bamyan                         NA
#
#   NL_NAME_1   TYPE_1 ENGTYPE_1 CC_1 HASC_1   ISO_1  \
# 0        NA  Velayat  Province   NA  AF.BD      NA
# 1        NA  Velayat  Province   NA  AF.BG  AF-BDG
# 2        NA  Velayat  Province   NA  AF.BL  AF-BGL
# 3        NA  Velayat  Province   NA  AF.BK  AF-BAL
# 4        NA  Velayat  Province   NA  AF.BM  AF-BAM
#
#                                             geometry
# 0  MULTIPOLYGON (((71.11366 35.9713, 71.10155 35....
# 1  MULTIPOLYGON (((63.76845 34.52948, 63.75823 34...
# 2  MULTIPOLYGON (((68.05261 35.08151, 68.0389 35....
# ...

# %%
adm1_layers['HASC_1'] = adm1_layers['HASC_1'].str.replace('.', '-')

# %%
adm1_layers['ISO_1'] = adm1_layers.apply(
    lambda row: row['HASC_1'] if row['ISO_1'] == 'NA' and row['HASC_1'] not in adm1_layers['ISO_1'].values else row['ISO_1'], 
    axis=1
)

# %%
adm1_layers
# Out:
#      GID_0      COUNTRY     GID_1              NAME_1  \
# 0      AFG  Afghanistan   AFG.1_1          Badakhshan
# 1      AFG  Afghanistan   AFG.2_1             Badghis
# 2      AFG  Afghanistan   AFG.3_1             Baghlan
# 3      AFG  Afghanistan   AFG.4_1               Balkh
# 4      AFG  Afghanistan   AFG.5_1              Bamyan
# ...    ...          ...       ...                 ...
# 3657   ZWE     Zimbabwe   ZWE.6_1    Mashonaland West
# 3658   ZWE     Zimbabwe   ZWE.7_1            Masvingo
# 3659   ZWE     Zimbabwe   ZWE.8_1  Matabeleland North
# 3660   ZWE     Zimbabwe   ZWE.9_1  Matabeleland South
# 3661   ZWE     Zimbabwe  ZWE.10_1            Midlands
#
#                       VARNAME_1 NL_NAME_1    TYPE_1 ENGTYPE_1 CC_1 HASC_1  \
# 0                      Badahšan        NA   Velayat  Province   NA  AF-BD
# 1      Badghes|Badghisat|Badgis        NA   Velayat  Province   NA  AF-BG
# 2                Baglan|Bughlan        NA   Velayat  Province   NA  AF-BL
# ...

# %%
print(adm0_layers.columns)
# Out:
# Index(['GID_0', 'COUNTRY', 'geometry'], dtype='object')

# %%
country_column = 'COUNTRY'
state_name = 'NAME_1'
district_name = 'NAME_2'

# %%
output_dir = 'D:/working/PhD/work/2024/November_2024/metaminer/geojsons/'

# %%
os.makedirs(output_dir, exist_ok = True)

# %%
# country_boudary =   adm0_layers[adm0_layers['COUNTRY'] == 'India']
# states_boundary = adm1_layers[adm1_layers['COUNTRY'] == 'India']

# %%
# country_boudary
# Out:
#     GID_0 COUNTRY                                           geometry
# 106   IND   India  MULTIPOLYGON (((76.97542 8.38514, 76.97486 8.3...
# 107   Z01   India  MULTIPOLYGON (((75.07161 32.48296, 75.06268 32...
# 108   Z04   India  MULTIPOLYGON (((78.65135 32.09228, 78.65241 32...
# 109   Z05   India  MULTIPOLYGON (((80.08794 30.79071, 80.08796 30...
# 110   Z07   India  MULTIPOLYGON (((94.19125 27.49632, 94.1869 27....
# 111   Z09   India  MULTIPOLYGON (((78.90891 31.25886, 78.91309 31...

# %%
for country, group in adm1_layers.groupby(country_column):
    # country_boudary =   adm0_layers[adm0_layers['COUNTRY'] == country]
    states_boundary = adm1_layers[adm1_layers['COUNTRY'] == country]
    country_three_letter_code = group['GID_0'].iloc[0]
    # combined = gpd.GeoDataFrame(pd.concat([country_boudary, states_boundary], ignore_index=True))
    
    output_path = os.path.join(output_dir, f"{country_three_letter_code}_states.json")
    states_boundary.to_file(output_path, driver = 'GeoJSON')
    print(f"Saved {country} data to {output_path}")

print("All done!")
# Out:
# Saved Afghanistan data to D:/working/PhD/work/2024/November_2024/metaminer/geojsons/AFG_states.json
# Saved Akrotiri and Dhekelia data to D:/working/PhD/work/2024/November_2024/metaminer/geojsons/XAD_states.json
# Saved Albania data to D:/working/PhD/work/2024/November_2024/metaminer/geojsons/ALB_states.json
# Saved Algeria data to D:/working/PhD/work/2024/November_2024/metaminer/geojsons/DZA_states.json
# Saved American Samoa data to D:/working/PhD/work/2024/November_2024/metaminer/geojsons/ASM_states.json
# Saved Andorra data to D:/working/PhD/work/2024/November_2024/metaminer/geojsons/AND_states.json
# Saved Angola data to D:/working/PhD/work/2024/November_2024/metaminer/geojsons/AGO_states.json
# Saved Anguilla data to D:/working/PhD/work/2024/November_2024/metaminer/geojsons/AIA_states.json
# Saved Antigua and Barbuda data to D:/working/PhD/work/2024/November_2024/metaminer/geojsons/ATG_states.json
# ...
